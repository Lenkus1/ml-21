# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path

import numpy as np

sys.path.insert(0, "..") 
from src.data import make_dataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rawdatadir = Path("..") / 'data' / 'raw'

# %%
housing = make_dataset.save_raw(rawdatadir)
# Out:
# 2021-08-16 20:23:08.521 | INFO     | src.data.make_dataset:save_raw:65 - Saving data to ../data/raw

# %%
(X_train, y_train), (X_valid, y_valid), (X_test, y_test) = make_dataset.split(housing.data, housing.target, train_size=0.8)
# Out:
# 2021-08-16 20:23:08.616 | INFO     | src.data.make_dataset:split:33 - Splitting data into 0.8 trainsize.

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.boxplot(X_train);

# %%
X_train, X_valid, X_test = make_dataset.scale([X_train, X_valid, X_test])

# %%
plt.boxplot(X_train);

# %%
outputdir = Path("..") / 'data' / 'processed'
make_dataset.process(rawdatadir, outputdir)
# Out:
# 2021-08-16 20:23:12.014 | INFO     | src.data.make_dataset:process:70 - making final data set from raw data
# 2021-08-16 20:23:12.030 | INFO     | src.data.make_dataset:save_raw:65 - Saving data to ../data/raw
# 2021-08-16 20:23:12.031 | INFO     | src.data.make_dataset:split:33 - Splitting data into 0.8 trainsize.
# 2021-08-16 20:23:12.036 | INFO     | src.data.make_dataset:process:76 - Scaling data
# 2021-08-16 20:23:12.041 | INFO     | src.data.make_dataset:process:82 - Saving scaled data to ../data/processed/data.npy

# %%
datafile = outputdir / "data.npy"
data = np.load(datafile, allow_pickle=True)

# %%
len(data)
# Out:
# 3
